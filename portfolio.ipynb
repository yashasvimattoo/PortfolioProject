# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/danielgrijalvas/movies/movies.csv

# %%
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None



# Now we need to read in the data
df = pd.read_csv(r'/kaggle/input/datasets/danielgrijalvas/movies/movies.csv')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# lets see if there is any missing data
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col,pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# name        0
# rating      0
# genre       0
# year        0
# released    0
# score       0
# votes       0
# director    0
# writer      0
# star        0
# country     0
# budget      0
# gross       0
# company     0
# runtime     0
# dtype: int64

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
df['budget']=df['budget'].astype("int64")
df['gross']=df['budget'].astype("int64")

# %%
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
# create correct year column
df['yearcorrect'] = df['released'].str.extract('([0-9]{4})')
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
df=df.sort_values(by=['gross'], inplace=False , ascending=False)

# %%
#pd.set_option("display.max_rows", None)
#agar sara data dekhna ho toh

# %%
# drop any duplicates
df.drop_duplicates()
# Out:
#                                           name   rating   genre  year  \
# 7445                         Avengers: Endgame    PG-13  Action  2019
# 7244                    Avengers: Infinity War    PG-13  Action  2018
# 7075   Star Wars: Episode VIII - The Last Jedi    PG-13  Action  2017
# 7066                            Justice League    PG-13  Action  2017
# 5060  Pirates of the Caribbean: at World's End    PG-13  Action  2007
# ...                                        ...      ...     ...   ...
# 2211                            The Living End  Unrated  Comedy  1992
# 5114                       Paranormal Activity        R  Horror  2007
# 4507                                    Primer    PG-13   Drama  2004
# 2093                               El Mariachi        R  Action  1992
# 3318                                 Following        R   Crime  1998
#
#                                released  score     votes           director  \
# ...

# %%
df
# Out:
#                                           name   rating   genre  year  \
# 7445                         Avengers: Endgame    PG-13  Action  2019
# 7244                    Avengers: Infinity War    PG-13  Action  2018
# 7075   Star Wars: Episode VIII - The Last Jedi    PG-13  Action  2017
# 7066                            Justice League    PG-13  Action  2017
# 5060  Pirates of the Caribbean: at World's End    PG-13  Action  2007
# ...                                        ...      ...     ...   ...
# 2211                            The Living End  Unrated  Comedy  1992
# 5114                       Paranormal Activity        R  Horror  2007
# 4507                                    Primer    PG-13   Drama  2004
# 2093                               El Mariachi        R  Action  1992
# 3318                                 Following        R   Crime  1998
#
#                                released  score     votes           director  \
# ...

# %%
#budget high correlation
#company high correlation

# %%
# scatter plot with budget vs gross
plt.scatter(x=df['budget'],y=df['gross'])
plt.title('budget vs gross earnings')
plt.xlabel('budget for film')
plt.ylabel('gross earnings')
plt.show()

# %%
df.head()
# Out:
#                                           name rating   genre  year  \
# 7445                         Avengers: Endgame  PG-13  Action  2019
# 7244                    Avengers: Infinity War  PG-13  Action  2018
# 7075   Star Wars: Episode VIII - The Last Jedi  PG-13  Action  2017
# 7066                            Justice League  PG-13  Action  2017
# 5060  Pirates of the Caribbean: at World's End  PG-13  Action  2007
#
#                                released  score     votes        director  \
# 7445     April 26, 2019 (United States)    8.4  903000.0   Anthony Russo
# 7244     April 27, 2018 (United States)    8.4  897000.0   Anthony Russo
# 7075  December 15, 2017 (United States)    7.0  581000.0    Rian Johnson
# 7066  November 17, 2017 (United States)    6.1  418000.0     Zack Snyder
# 5060       May 25, 2007 (United States)    7.1  608000.0  Gore Verbinski
#
#                   writer               star        country     budget  \
# ...

# %%
# plot budget vs gross using seaborn

sns.regplot(x='budget', y='gross', data=df, scatter_kws={'color':"red"},line_kws={'color':'blue'})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
#lets start looking at correlation
# correlation are of three types pearson,kendall,spearman 
df.corr(numeric_only=True)
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.327722  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.072001  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.439675  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  1.000000  0.318695
# gross    0.327722  0.072001  0.439675  1.000000  1.000000  0.318695
# runtime  0.075077  0.414068  0.352303  0.318695  0.318695  1.000000

# %%
df.corr(method='pearson',numeric_only=True)
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.327722  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.072001  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.439675  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  1.000000  0.318695
# gross    0.327722  0.072001  0.439675  1.000000  1.000000  0.318695
# runtime  0.075077  0.414068  0.352303  0.318695  0.318695  1.000000

# %%
df.corr(method='kendall',numeric_only=True)
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.039389  0.296512  0.220833  0.220833  0.064824
# score    0.039389  1.000000  0.350185 -0.006406 -0.006406  0.292254
# votes    0.296512  0.350185  1.000000  0.346274  0.346274  0.205344
# budget   0.220833 -0.006406  0.346274  1.000000  1.000000  0.231278
# gross    0.220833 -0.006406  0.346274  1.000000  1.000000  0.231278
# runtime  0.064824  0.292254  0.205344  0.231278  0.231278  1.000000

# %%
df.corr(method='spearman',numeric_only=True)
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.057741  0.427623  0.312886  0.312886  0.095444
# score    0.057741  1.000000  0.495409 -0.009971 -0.009971  0.412155
# votes    0.427623  0.495409  1.000000  0.493461  0.493461  0.300621
# budget   0.312886 -0.009971  0.493461  1.000000  1.000000  0.330794
# gross    0.312886 -0.009971  0.493461  1.000000  1.000000  0.330794
# runtime  0.095444  0.412155  0.300621  0.330794  0.330794  1.000000

# %%
#high correlation between budget and gross : i was right their is high corr

# %%
correlation_matrix= df.corr(method='pearson', numeric_only= True)
sns.heatmap(correlation_matrix, annot=True)
plt.title('correlation for numeric features')
plt.xlabel('Movie features')
plt.ylabel('Movie features')
plt.show()

# %%
# looks at company
df_numerized = df.copy()

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype =='object'):
        df_numerized[col_name]=df_numerized[col_name].astype('category')
        df_numerized[col_name]=df_numerized[col_name].cat.codes

df_numerized
#jo b obj th unko category krke with the help of cat code numerical value de di
# Out:
#       name  rating  genre  year  released  score     votes  director  writer  \
# 7445   388       5      0  2019       137    8.4  903000.0       105     513
# 7244   389       5      0  2018       145    8.4  897000.0       105     513
# 7075  3644       5      0  2017       500    7.0  581000.0      1589    2487
# 7066  2124       5      0  2017      1996    6.1  418000.0      2057    1402
# 5060  2987       5      0  2007      1844    7.1  608000.0       674    2927
# ...    ...     ...    ...   ...       ...    ...       ...       ...     ...
# 2211  4395       8      4  1992       317    6.5    2900.0       685    1094
# 5114  2906       6      9  2007      2199    6.3  225000.0      1452    2292
# 4507  3062       5      6  2004      1860    6.9  101000.0      1768    2768
# 2093  1257       6      0  1992       781    6.9   64000.0      1668    2601
# 3318  1461       6      5  1998      2112    7.5   89000.0       317     516
#
# ...

# %%
df
# Out:
#                                           name   rating   genre  year  \
# 7445                         Avengers: Endgame    PG-13  Action  2019
# 7244                    Avengers: Infinity War    PG-13  Action  2018
# 7075   Star Wars: Episode VIII - The Last Jedi    PG-13  Action  2017
# 7066                            Justice League    PG-13  Action  2017
# 5060  Pirates of the Caribbean: at World's End    PG-13  Action  2007
# ...                                        ...      ...     ...   ...
# 2211                            The Living End  Unrated  Comedy  1992
# 5114                       Paranormal Activity        R  Horror  2007
# 4507                                    Primer    PG-13   Drama  2004
# 2093                               El Mariachi        R  Action  1992
# 3318                                 Following        R   Crime  1998
#
#                                released  score     votes           director  \
# ...

# %%
correlation_matrix= df_numerized.corr(method='pearson', numeric_only= True)
sns.heatmap(correlation_matrix, annot=True)
plt.title('correlation for numeric features')
plt.xlabel('Movie features')
plt.ylabel('Movie features')
plt.show()

# %%
df_numerized.corr()
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000 -0.029234  0.010996  0.025542 -0.006152  0.014450
# rating      -0.029234  1.000000  0.147796  0.019499  0.018083  0.065983
# genre        0.010996  0.147796  1.000000 -0.073167  0.022142  0.035106
# year         0.025542  0.019499 -0.073167  1.000000 -0.001740  0.056386
# released    -0.006152  0.018083  0.022142 -0.001740  1.000000  0.045874
# score        0.014450  0.065983  0.035106  0.056386  0.045874  1.000000
# votes        0.012615  0.006031 -0.135990  0.206021  0.028833  0.474256
# director     0.015246  0.014656 -0.008553 -0.038354  0.002308  0.005413
# writer       0.012880 -0.003149  0.017578 -0.025908  0.008072  0.012843
# star        -0.006882  0.009196  0.003341 -0.032157  0.015706  0.007296
# country     -0.025490  0.008230 -0.009164 -0.066748 -0.017228 -0.043051
# budget       0.023392 -0.203946 -0.368523  0.327722  0.019952  0.072001
# ...

# %%
correlation_mat= df_numerized.corr()
corr_pairs= correlation_mat.unstack()
corr_pairs
#unstack corr dilhata h alag format mei!
# Out:
# name         name           1.000000
#              rating        -0.029234
#              genre          0.010996
#              year           0.025542
#              released      -0.006152
#                               ...
# yearcorrect  budget         0.320312
#              gross          0.320312
#              company       -0.018806
#              runtime        0.075294
#              yearcorrect    1.000000
# Length: 256, dtype: float64

# %%
sorted_pairs=corr_pairs.sort_values()
sorted_pairs
# Out:
# genre        budget        -0.368523
#              gross         -0.368523
# gross        genre         -0.368523
# budget       genre         -0.368523
#              rating        -0.203946
#                               ...
# gross        budget         1.000000
# company      company        1.000000
# gross        gross          1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# Length: 256, dtype: float64

# %%
high_corr=sorted_pairs[(sorted_pairs)>0.5]
high_corr
# Out:
# year         yearcorrect    0.998726
# yearcorrect  year           0.998726
# genre        genre          1.000000
# year         year           1.000000
# director     director       1.000000
# votes        votes          1.000000
# released     released       1.000000
# score        score          1.000000
# rating       rating         1.000000
# name         name           1.000000
# writer       writer         1.000000
# star         star           1.000000
# budget       gross          1.000000
#              budget         1.000000
# country      country        1.000000
# gross        budget         1.000000
# company      company        1.000000
# gross        gross          1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# dtype: float64

# %%
# votes and budget have the highest corr to gross earnings
# company has low corr
